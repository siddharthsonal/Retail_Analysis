# %%
import pandas as pd
customer_profile = pd.read_csv("D:/coding ninja project git/retail_analysis_case_study/datasets/customer_profiles.csv")

# %%
customer_profile
# Out:
#      CustomerID  Age  Gender Location  JoinDate
# 0             1   63   Other     East  01/01/20
# 1             2   63    Male    North  02/01/20
# 2             3   34   Other    North  03/01/20
# 3             4   19   Other      NaN  04/01/20
# 4             5   57    Male    North  05/01/20
# ..          ...  ...     ...      ...       ...
# 995         996   36  Female    North  27/12/22
# 996         997   24    Male     West  28/12/22
# 997         998   22   Other      NaN  29/12/22
# 998         999   57    Male     West  30/12/22
# 999        1000   38   Other     West  01/01/23
#
# [1000 rows x 5 columns]

# %%
customer_profile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   CustomerID  1000 non-null   int64
#  1   Age         1000 non-null   int64
#  2   Gender      1000 non-null   object
#  3   Location    987 non-null    object
#  4   JoinDate    1000 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 39.2+ KB

# %%
customer_profile.isnull().sum()
# Out:
# CustomerID     0
# Age            0
# Gender         0
# Location      13
# JoinDate       0
# dtype: int64

# %%
customer_profile.isnull().any()
# Out:
# CustomerID    False
# Age           False
# Gender        False
# Location       True
# JoinDate      False
# dtype: bool

# %%
customer_profile.isnull().any().any()
# Out:
# np.True_

# %%
customer_profile['Location'].hasnans
# Out:
# True
